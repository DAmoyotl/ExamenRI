# %%
import os

from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer

basepath = './resources/dataset'
with os.scandir(basepath) as entries:
    for entry in entries:
        if entry.is_file():
            infile = open(entry, "r")
            for line in infile:
            basepath = [[stem(word) for word in sentence.split(" ")] for sentence in basepath]
# Out:
#   File "<ipython-input-3-8457c560c98c>", line 8
#     documents = [[stem(word) for word in sentence.split(" ")] for sentence in documents]
#             ^
# IndentationError: expected an indented block
