# %%
import os

from stemming.porter2 import stem

basepath = './resources/dataset'
with os.scandir(basepath) as entries:
    for entry in entries:
        if entry.is_file():
            infile = open(entry, "r")
            for line in infile:
                basepath = [[stem(word) for word in sentence.split(" ")] for sentence in basepath]
# Out:
#   File "<ipython-input-4-2cc3dab218dd>", line 11
#     basepath = [[stem(word) for word in sentence.split(" ")] for sentence in basepath]
#            ^
# IndentationError: expected an indented block
